# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=input_shape),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu', input_shape=input_shape),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# c:\Users\beris\OneDrive\Radna površina\PSU-labs\labs\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - binary_accuracy: 0.7419 - loss: 0.5358 - val_binary_accuracy: 0.8047 - val_loss: 0.4459
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8057 - loss: 0.4175 - val_binary_accuracy: 0.8167 - val_loss: 0.4031
# Epoch 3/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8108 - loss: 0.4056 - val_binary_accuracy: 0.8203 - val_loss: 0.3916
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8151 - loss: 0.3970 - val_binary_accuracy: 0.8189 - val_loss: 0.3870
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8190 - loss: 0.3924 - val_binary_accuracy: 0.8233 - val_loss: 0.3818
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8226 - loss: 0.3838 - val_binary_accuracy: 0.8263 - val_loss: 0.3789
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8228 - loss: 0.3804 - val_binary_accuracy: 0.8273 - val_loss: 0.3759
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8231 - loss: 0.3790 - val_binary_accuracy: 0.8265 - val_loss: 0.3744
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8279 - loss: 0.3743 - val_binary_accuracy: 0.8285 - val_loss: 0.3714
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8287 - loss: 0.3707 - val_binary_accuracy: 0.8320 - val_loss: 0.3679
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8272 - loss: 0.3710 - val_binary_accuracy: 0.8319 - val_loss: 0.3679
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8312 - loss: 0.3656 - val_binary_accuracy: 0.8323 - val_loss: 0.3662
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8313 - loss: 0.3640 - val_binary_accuracy: 0.8320 - val_loss: 0.3667
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8342 - loss: 0.3606 - val_binary_accuracy: 0.8318 - val_loss: 0.3657
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8361 - loss: 0.3571 - val_binary_accuracy: 0.8339 - val_loss: 0.3630
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8342 - loss: 0.3581 - val_binary_accuracy: 0.8346 - val_loss: 0.3605
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8362 - loss: 0.3539 - val_binary_accuracy: 0.8357 - val_loss: 0.3592
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8390 - loss: 0.3525 - val_binary_accuracy: 0.8337 - val_loss: 0.3609
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8378 - loss: 0.3509 - val_binary_accuracy: 0.8369 - val_loss: 0.3579
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8378 - loss: 0.3530 - val_binary_accuracy: 0.8348 - val_loss: 0.3587
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8396 - loss: 0.3489 - val_binary_accuracy: 0.8355 - val_loss: 0.3576
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8392 - loss: 0.3479 - val_binary_accuracy: 0.8368 - val_loss: 0.3559
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8403 - loss: 0.3459 - val_binary_accuracy: 0.8384 - val_loss: 0.3551
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8427 - loss: 0.3448 - val_binary_accuracy: 0.8381 - val_loss: 0.3542
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8407 - loss: 0.3461 - val_binary_accuracy: 0.8387 - val_loss: 0.3537
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8429 - loss: 0.3434 - val_binary_accuracy: 0.8392 - val_loss: 0.3544
# Epoch 27/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8433 - loss: 0.3405 - val_binary_accuracy: 0.8361 - val_loss: 0.3557
# Epoch 28/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8441 - loss: 0.3402 - val_binary_accuracy: 0.8392 - val_loss: 0.3523
# Epoch 29/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8435 - loss: 0.3402 - val_binary_accuracy: 0.8377 - val_loss: 0.3535
# Epoch 30/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8454 - loss: 0.3366 - val_binary_accuracy: 0.8399 - val_loss: 0.3517
# Epoch 31/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8432 - loss: 0.3380 - val_binary_accuracy: 0.8389 - val_loss: 0.3515
# Epoch 32/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8461 - loss: 0.3365 - val_binary_accuracy: 0.8383 - val_loss: 0.3516
# Epoch 33/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.8447 - loss: 0.3368 - val_binary_accuracy: 0.8413 - val_loss: 0.3521
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?
